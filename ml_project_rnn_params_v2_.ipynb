# %%
import numpy as np
import pandas as pd
import pickle
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.layers import Input, Embedding, Dense, Flatten, Dropout, GRU, LSTM
from tensorflow.keras.models import Model
from sklearn.preprocessing import OneHotEncoder
from pathlib import Path, PureWindowsPath

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !unzip ./dev_dataset_csv_small.zip
# Out:
# Archive:  ./dev_dataset_csv_small.zip
#   inflating: train_set.csv
#   inflating: val_set.csv

# %%
'''
Define a function for loading the data from a given folder path. 
(note: in this project, training, validation and test datasets are located in different folders)
'''
# You should write some code based on the content of "dataset-visualization.py"

# To make things easier, first, create a function to load data for the first problem (beam prediction using past beams).
# Have clear the dataset composition before doing this.
# The 9th column (starting from 1) would be the true labels column (we want to predict the first future beam)
# You should one-hot-encode the true labels columns. There's an sklearn function for this.

def load_beam_data(path):
    df = pd.read_csv(path)
    feature_cols = ["Beam 1", "Beam 2", "Beam 3", "Beam 4", "Beam 5", "Beam 6", "Beam 7", "Beam 8"]
    target_cols = ["Beam 9"]
    features = df[feature_cols].to_numpy()
    target = df[target_cols].to_numpy()
    return features, target

# %%
'''
Define functions for creating a specific type of network architecture.
In this project, we will implement a first architecture based on GRUs (baseline approach) using only the beam indexes as features.
A second architecture (based on 3D CNN) will additionally exploit camera images to improve the prediction accuracy.
'''
# [1] https://arxiv.org/abs/2002.02445; Github: https://github.com/malrabeiah/VABT/tree/master

# Create a method that returns the first model using keras APIs
def build_gru_model(input_size, codebook_size, embed_size=50, hidden_size=20, num_layers=2, dropout=0.2, return_seq=False):

    inputs = Input(shape=(input_size,), name="input_layer")
    # Add an embedding layer (as discussed in paper [1]): https://keras.io/api/layers/core_layers/embedding/
    # The output of the embedding layer should have shape: [batch_size, input_size, embed_size]
    embedding = Embedding(codebook_size, embed_size, name="embedding_layer")(inputs)

    # Add "num_layers" GRU layers with "hidden_size" units. Use the parameters provided in [1]
    # https://keras.io/api/layers/recurrent_layers/gru/
    layer_output = embedding
    for i in range(num_layers):
        if i+1 == num_layers:
            layer_output = GRU(hidden_size, return_sequences=return_seq, dropout=dropout,
                               name="recurrent_layer_"+str(i+1))(layer_output)
        else:
            layer_output = GRU(hidden_size, return_sequences=True, dropout=dropout,
                               name="recurrent_layer_"+str(i+1))(layer_output)
    layer_output = Flatten()(layer_output)
    # Add Softmax activation layer.
    out = Dense(codebook_size, activation='softmax')(layer_output)

    model = Model(inputs=inputs, outputs=out)
    return model

# %%
# load training, validation and test data (note: there's no need to scale the data)
train_path = "./train_set.csv"
val_path = "./val_set.csv"
Xtr, ytr = load_beam_data(train_path)
Xval, yval = load_beam_data(val_path)
# Xts, yts = load_beam_data(test_path) # Test data is formatted in a differemt way, need to modify the loader
print(f"Training data shape: {Xtr.shape}")
print(f"Validation data shape: {Xval.shape}")
# One-hot-encoding of training and val target
enc = OneHotEncoder()
enc.fit_transform(np.vstack((ytr, [0]))) # needed to manually add codeword "0" in order to one-hot-code to the correct codebook size
# It seems codeword corresponding to index 0 has not been collected in the data
ytr_e = enc.transform(ytr).toarray()
yval_e = enc.transform(yval).toarray()
print(f"Encoded training target shape: {ytr_e.shape}")
print(f"Encoded validation target shape: {yval_e.shape}")
# Out:
# Training data shape: (281100, 8)
# Validation data shape: (120468, 8)
# Encoded training target shape: (281100, 128)
# Encoded validation target shape: (120468, 128)

# %%
K.clear_session()
input_size = Xtr.shape[1]
codebook_size = np.max(Xtr)+1
print(codebook_size)
# create a model to verify the correctness
model = build_gru_model(input_size, int(codebook_size), return_seq=True)
print(model.summary())
# Out:
# 128.0
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 8)]               0
# _________________________________________________________________
# embedding_layer (Embedding)  (None, 8, 50)             6400
# _________________________________________________________________
# recurrent_layer_1 (GRU)      (None, 8, 20)             4320
# _________________________________________________________________
# recurrent_layer_2 (GRU)      (None, 8, 20)             2520
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               20608
# =================================================================
# Total params: 33,848
# Trainable params: 33,848
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
####### Parameters Optimization #########
lr_test = np.array([2e-4, 1e-3, 5e-3])
nlayers_test = np.array([2,3,4])
ret_seq_test = np.array([False, True])
embed_size_test = np.array([50, 100])
hidden_size_test = np.array([20, 40])
dropout_test = np.array([0.2, 0.5])
n_tests = lr_test.size*lr_test.size*ret_seq_test.size*embed_size_test.size*hidden_size_test.size*dropout_test.size
print(f"The nummber of combinations to test is: {n_tests}")
# Out:
# The nummber of combinations to test is: 144

# %%
# trying saving on drive 
with open('./drive/MyDrive/test.pickle', 'wb') as f:
    pickle.dump([nlayers_test, lr_test], f)

# %%
n_epochs = 100
batch_size = 1000
tr_accuracy = np.zeros((lr_test.size,lr_test.size,ret_seq_test.size,embed_size_test.size,hidden_size_test.size,dropout_test.size,n_epochs))
val_accuracy = np.zeros(tr_accuracy.shape)
print(tr_accuracy.shape)
print(val_accuracy.shape)

for i1 , lr_i in enumerate(lr_test):
    for i2 , nlayers_i in enumerate(nlayers_test):
        for i3 , ret_seq_i in enumerate(ret_seq_test):
            for i4 , embed_size_i in enumerate(embed_size_test):
                for i5 , hidden_size_i in enumerate(hidden_size_test):
                    for i6 , dropout_i in enumerate(dropout_test):
                        K.clear_session()
                        model = build_gru_model(input_size, int(codebook_size), num_layers=nlayers_i, 
                                                embed_size=embed_size_i, hidden_size=hidden_size_i,
                                                return_seq=ret_seq_i, dropout=dropout_i)
                        # compile the model with proper optimizer
                        opt = Adam(lr=lr_i, amsgrad=True)
                        model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
                        hist = model.fit(Xtr, ytr_e, validation_data=(Xval, yval_e), batch_size=batch_size, epochs=n_epochs)
                        tr_accuracy[i1,i2,i3,i4,i5,i6,:] = hist.history['accuracy']
                        val_accuracy[i1,i2,i3,i4,i5,i6,:] = hist.history['val_accuracy']

with open('./drive/MyDrive/param_optim.pickle', 'wb') as f:
    pickle.dump([tr_accuracy, val_accuracy], f)

# %%
# retrain using the best parameters found in the steps above
K.clear_session()
n_epochs = 200
batch_size = 1000
# best parameters
lr = 1e-3
nlayers = 3
embed_size = 100
ret_seq = True
hidden_size = 40
dropout = 0.2

model_path = "./drive/MyDrive/model-gru-{epoch:02d}.hdf5"
model_checkpoint = ModelCheckpoint(model_path, monitor="val_accuracy", save_best_only=True, verbose=1)

# decaying lr callback
up_epoch = 50
decay_factor = 0.5
def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % up_epoch == 0) and (epoch != 0):
        lr = lr * decay_factor
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

model = build_gru_model(input_size, int(codebook_size), num_layers=nlayers, 
                        embed_size=embed_size, hidden_size=hidden_size,
                        return_seq=ret_seq, dropout=dropout)
opt = Adam(lr=lr, amsgrad=True)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
hist = model.fit(Xtr, ytr_e, validation_data=(Xval, yval_e), batch_size=batch_size, 
                 epochs=n_epochs, callbacks=[model_checkpoint, lr_scheduler], workers=8)
# Out:
# Epoch 1/200
# 277/282 [============================>.] - ETA: 0s - loss: 2.1072 - accuracy: 0.4908
# Epoch 00001: val_accuracy improved from -inf to 0.73126, saving model to ./drive/MyDrive/model-gru-01.hdf5
# 282/282 [==============================] - 4s 13ms/step - loss: 2.0940 - accuracy: 0.4940 - val_loss: 1.1383 - val_accuracy: 0.7313
# Epoch 2/200
# 277/282 [============================>.] - ETA: 0s - loss: 1.0401 - accuracy: 0.7624
# Epoch 00002: val_accuracy improved from 0.73126 to 0.79463, saving model to ./drive/MyDrive/model-gru-02.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 1.0391 - accuracy: 0.7626 - val_loss: 0.9024 - val_accuracy: 0.7946
# Epoch 3/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.9072 - accuracy: 0.7949
# Epoch 00003: val_accuracy improved from 0.79463 to 0.81238, saving model to ./drive/MyDrive/model-gru-03.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.9067 - accuracy: 0.7950 - val_loss: 0.8385 - val_accuracy: 0.8124
# Epoch 4/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.8562 - accuracy: 0.8080
# Epoch 00004: val_accuracy improved from 0.81238 to 0.82202, saving model to ./drive/MyDrive/model-gru-04.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.8552 - accuracy: 0.8083 - val_loss: 0.8058 - val_accuracy: 0.8220
# Epoch 5/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.8210 - accuracy: 0.8170
# Epoch 00005: val_accuracy improved from 0.82202 to 0.82746, saving model to ./drive/MyDrive/model-gru-05.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.8211 - accuracy: 0.8169 - val_loss: 0.7838 - val_accuracy: 0.8275
# Epoch 6/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.7998 - accuracy: 0.8226
# Epoch 00006: val_accuracy improved from 0.82746 to 0.83063, saving model to ./drive/MyDrive/model-gru-06.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.7999 - accuracy: 0.8226 - val_loss: 0.7728 - val_accuracy: 0.8306
# Epoch 7/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.7841 - accuracy: 0.8263
# Epoch 00007: val_accuracy improved from 0.83063 to 0.83452, saving model to ./drive/MyDrive/model-gru-07.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.7845 - accuracy: 0.8262 - val_loss: 0.7602 - val_accuracy: 0.8345
# Epoch 8/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.7707 - accuracy: 0.8295
# Epoch 00008: val_accuracy improved from 0.83452 to 0.83703, saving model to ./drive/MyDrive/model-gru-08.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.7711 - accuracy: 0.8294 - val_loss: 0.7522 - val_accuracy: 0.8370
# Epoch 9/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.7609 - accuracy: 0.8318
# Epoch 00009: val_accuracy improved from 0.83703 to 0.83722, saving model to ./drive/MyDrive/model-gru-09.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.7609 - accuracy: 0.8318 - val_loss: 0.7472 - val_accuracy: 0.8372
# Epoch 10/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.7531 - accuracy: 0.8331
# Epoch 00010: val_accuracy improved from 0.83722 to 0.83806, saving model to ./drive/MyDrive/model-gru-10.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.7531 - accuracy: 0.8331 - val_loss: 0.7435 - val_accuracy: 0.8381
# Epoch 11/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.7454 - accuracy: 0.8345
# Epoch 00011: val_accuracy improved from 0.83806 to 0.84006, saving model to ./drive/MyDrive/model-gru-11.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.7461 - accuracy: 0.8344 - val_loss: 0.7376 - val_accuracy: 0.8401
# Epoch 12/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.7390 - accuracy: 0.8360
# Epoch 00012: val_accuracy improved from 0.84006 to 0.84065, saving model to ./drive/MyDrive/model-gru-12.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.7389 - accuracy: 0.8361 - val_loss: 0.7349 - val_accuracy: 0.8406
# Epoch 13/200
# 282/282 [==============================] - ETA: 0s - loss: 0.7341 - accuracy: 0.8367
# Epoch 00013: val_accuracy improved from 0.84065 to 0.84077, saving model to ./drive/MyDrive/model-gru-13.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.7341 - accuracy: 0.8367 - val_loss: 0.7303 - val_accuracy: 0.8408
# Epoch 14/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.7302 - accuracy: 0.8381
# Epoch 00014: val_accuracy improved from 0.84077 to 0.84139, saving model to ./drive/MyDrive/model-gru-14.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.7299 - accuracy: 0.8381 - val_loss: 0.7303 - val_accuracy: 0.8414
# Epoch 15/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.7257 - accuracy: 0.8388
# Epoch 00015: val_accuracy improved from 0.84139 to 0.84321, saving model to ./drive/MyDrive/model-gru-15.hdf5
# 282/282 [==============================] - 3s 10ms/step - loss: 0.7257 - accuracy: 0.8388 - val_loss: 0.7259 - val_accuracy: 0.8432
# Epoch 16/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.7195 - accuracy: 0.8391
# Epoch 00016: val_accuracy did not improve from 0.84321
# 282/282 [==============================] - 3s 10ms/step - loss: 0.7202 - accuracy: 0.8390 - val_loss: 0.7231 - val_accuracy: 0.8428
# Epoch 17/200
# 282/282 [==============================] - ETA: 0s - loss: 0.7174 - accuracy: 0.8405
# Epoch 00017: val_accuracy improved from 0.84321 to 0.84324, saving model to ./drive/MyDrive/model-gru-17.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.7174 - accuracy: 0.8405 - val_loss: 0.7229 - val_accuracy: 0.8432
# Epoch 18/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.7134 - accuracy: 0.8411
# Epoch 00018: val_accuracy improved from 0.84324 to 0.84333, saving model to ./drive/MyDrive/model-gru-18.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.7138 - accuracy: 0.8410 - val_loss: 0.7207 - val_accuracy: 0.8433
# Epoch 19/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.7118 - accuracy: 0.8414
# Epoch 00019: val_accuracy improved from 0.84333 to 0.84458, saving model to ./drive/MyDrive/model-gru-19.hdf5
# 282/282 [==============================] - 3s 10ms/step - loss: 0.7111 - accuracy: 0.8415 - val_loss: 0.7208 - val_accuracy: 0.8446
# Epoch 20/200
# 282/282 [==============================] - ETA: 0s - loss: 0.7080 - accuracy: 0.8418
# Epoch 00020: val_accuracy improved from 0.84458 to 0.84461, saving model to ./drive/MyDrive/model-gru-20.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.7080 - accuracy: 0.8418 - val_loss: 0.7192 - val_accuracy: 0.8446
# Epoch 21/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.8424
# Epoch 00021: val_accuracy improved from 0.84461 to 0.84466, saving model to ./drive/MyDrive/model-gru-21.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.7059 - accuracy: 0.8424 - val_loss: 0.7171 - val_accuracy: 0.8447
# Epoch 22/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.7033 - accuracy: 0.8428
# Epoch 00022: val_accuracy improved from 0.84466 to 0.84573, saving model to ./drive/MyDrive/model-gru-22.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.7031 - accuracy: 0.8428 - val_loss: 0.7162 - val_accuracy: 0.8457
# Epoch 23/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.7012 - accuracy: 0.8431
# Epoch 00023: val_accuracy did not improve from 0.84573
# 282/282 [==============================] - 3s 10ms/step - loss: 0.7009 - accuracy: 0.8432 - val_loss: 0.7153 - val_accuracy: 0.8450
# Epoch 24/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6995 - accuracy: 0.8434
# Epoch 00024: val_accuracy did not improve from 0.84573
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6994 - accuracy: 0.8434 - val_loss: 0.7140 - val_accuracy: 0.8453
# Epoch 25/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6967 - accuracy: 0.8439
# Epoch 00025: val_accuracy did not improve from 0.84573
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6967 - accuracy: 0.8440 - val_loss: 0.7127 - val_accuracy: 0.8455
# Epoch 26/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6951 - accuracy: 0.8443
# Epoch 00026: val_accuracy did not improve from 0.84573
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6953 - accuracy: 0.8442 - val_loss: 0.7127 - val_accuracy: 0.8453
# Epoch 27/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6926 - accuracy: 0.8451
# Epoch 00027: val_accuracy improved from 0.84573 to 0.84591, saving model to ./drive/MyDrive/model-gru-27.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6926 - accuracy: 0.8451 - val_loss: 0.7131 - val_accuracy: 0.8459
# Epoch 28/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6907 - accuracy: 0.8457
# Epoch 00028: val_accuracy improved from 0.84591 to 0.84631, saving model to ./drive/MyDrive/model-gru-28.hdf5
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6904 - accuracy: 0.8457 - val_loss: 0.7118 - val_accuracy: 0.8463
# Epoch 29/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6894 - accuracy: 0.8455
# Epoch 00029: val_accuracy did not improve from 0.84631
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6894 - accuracy: 0.8455 - val_loss: 0.7101 - val_accuracy: 0.8457
# Epoch 30/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6880 - accuracy: 0.8459
# Epoch 00030: val_accuracy improved from 0.84631 to 0.84698, saving model to ./drive/MyDrive/model-gru-30.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6878 - accuracy: 0.8459 - val_loss: 0.7092 - val_accuracy: 0.8470
# Epoch 31/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6866 - accuracy: 0.8458
# Epoch 00031: val_accuracy did not improve from 0.84698
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6862 - accuracy: 0.8459 - val_loss: 0.7087 - val_accuracy: 0.8467
# Epoch 32/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6836 - accuracy: 0.8470
# Epoch 00032: val_accuracy did not improve from 0.84698
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6846 - accuracy: 0.8468 - val_loss: 0.7079 - val_accuracy: 0.8457
# Epoch 33/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6831 - accuracy: 0.8466
# Epoch 00033: val_accuracy did not improve from 0.84698
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6833 - accuracy: 0.8466 - val_loss: 0.7083 - val_accuracy: 0.8463
# Epoch 34/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6825 - accuracy: 0.8466
# Epoch 00034: val_accuracy improved from 0.84698 to 0.84738, saving model to ./drive/MyDrive/model-gru-34.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6824 - accuracy: 0.8467 - val_loss: 0.7069 - val_accuracy: 0.8474
# Epoch 35/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6806 - accuracy: 0.8470
# Epoch 00035: val_accuracy did not improve from 0.84738
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6806 - accuracy: 0.8470 - val_loss: 0.7068 - val_accuracy: 0.8470
# Epoch 36/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6804 - accuracy: 0.8475
# Epoch 00036: val_accuracy improved from 0.84738 to 0.84760, saving model to ./drive/MyDrive/model-gru-36.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6800 - accuracy: 0.8475 - val_loss: 0.7071 - val_accuracy: 0.8476
# Epoch 37/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6791 - accuracy: 0.8474
# Epoch 00037: val_accuracy did not improve from 0.84760
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6789 - accuracy: 0.8474 - val_loss: 0.7057 - val_accuracy: 0.8471
# Epoch 38/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6782 - accuracy: 0.8475
# Epoch 00038: val_accuracy did not improve from 0.84760
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6782 - accuracy: 0.8474 - val_loss: 0.7054 - val_accuracy: 0.8476
# Epoch 39/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6767 - accuracy: 0.8475
# Epoch 00039: val_accuracy did not improve from 0.84760
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6767 - accuracy: 0.8475 - val_loss: 0.7055 - val_accuracy: 0.8474
# Epoch 40/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6754 - accuracy: 0.8478
# Epoch 00040: val_accuracy improved from 0.84760 to 0.84823, saving model to ./drive/MyDrive/model-gru-40.hdf5
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6755 - accuracy: 0.8477 - val_loss: 0.7057 - val_accuracy: 0.8482
# Epoch 41/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6736 - accuracy: 0.8484
# Epoch 00041: val_accuracy did not improve from 0.84823
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6737 - accuracy: 0.8484 - val_loss: 0.7056 - val_accuracy: 0.8482
# Epoch 42/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6727 - accuracy: 0.8488
# Epoch 00042: val_accuracy did not improve from 0.84823
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6727 - accuracy: 0.8488 - val_loss: 0.7053 - val_accuracy: 0.8482
# Epoch 43/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6721 - accuracy: 0.8486
# Epoch 00043: val_accuracy did not improve from 0.84823
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6721 - accuracy: 0.8486 - val_loss: 0.7048 - val_accuracy: 0.8478
# Epoch 44/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6725 - accuracy: 0.8485
# Epoch 00044: val_accuracy improved from 0.84823 to 0.84862, saving model to ./drive/MyDrive/model-gru-44.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6724 - accuracy: 0.8485 - val_loss: 0.7032 - val_accuracy: 0.8486
# Epoch 45/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6711 - accuracy: 0.8487
# Epoch 00045: val_accuracy did not improve from 0.84862
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6711 - accuracy: 0.8487 - val_loss: 0.7036 - val_accuracy: 0.8486
# Epoch 46/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6705 - accuracy: 0.8487
# Epoch 00046: val_accuracy did not improve from 0.84862
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6704 - accuracy: 0.8487 - val_loss: 0.7032 - val_accuracy: 0.8482
# Epoch 47/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6692 - accuracy: 0.8489
# Epoch 00047: val_accuracy did not improve from 0.84862
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6690 - accuracy: 0.8489 - val_loss: 0.7026 - val_accuracy: 0.8477
# Epoch 48/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6679 - accuracy: 0.8489
# Epoch 00048: val_accuracy did not improve from 0.84862
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6679 - accuracy: 0.8489 - val_loss: 0.7030 - val_accuracy: 0.8474
# Epoch 49/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6677 - accuracy: 0.8490
# Epoch 00049: val_accuracy did not improve from 0.84862
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6678 - accuracy: 0.8490 - val_loss: 0.7022 - val_accuracy: 0.8485
# Epoch 50/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6666 - accuracy: 0.8494
# Epoch 00050: val_accuracy did not improve from 0.84862
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6665 - accuracy: 0.8495 - val_loss: 0.7030 - val_accuracy: 0.8479
# Epoch 51/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6588 - accuracy: 0.8509
# Epoch 00051: val_accuracy improved from 0.84862 to 0.84930, saving model to ./drive/MyDrive/model-gru-51.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6588 - accuracy: 0.8508 - val_loss: 0.6976 - val_accuracy: 0.8493
# Epoch 52/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6582 - accuracy: 0.8512
# Epoch 00052: val_accuracy did not improve from 0.84930
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6582 - accuracy: 0.8512 - val_loss: 0.6974 - val_accuracy: 0.8492
# Epoch 53/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6570 - accuracy: 0.8517
# Epoch 00053: val_accuracy improved from 0.84930 to 0.84978, saving model to ./drive/MyDrive/model-gru-53.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6570 - accuracy: 0.8516 - val_loss: 0.6970 - val_accuracy: 0.8498
# Epoch 54/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6569 - accuracy: 0.8520
# Epoch 00054: val_accuracy improved from 0.84978 to 0.84999, saving model to ./drive/MyDrive/model-gru-54.hdf5
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6569 - accuracy: 0.8520 - val_loss: 0.6981 - val_accuracy: 0.8500
# Epoch 55/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6573 - accuracy: 0.8514
# Epoch 00055: val_accuracy did not improve from 0.84999
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6570 - accuracy: 0.8515 - val_loss: 0.6966 - val_accuracy: 0.8497
# Epoch 56/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6552 - accuracy: 0.8520
# Epoch 00056: val_accuracy did not improve from 0.84999
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6557 - accuracy: 0.8519 - val_loss: 0.6964 - val_accuracy: 0.8499
# Epoch 57/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6566 - accuracy: 0.8512
# Epoch 00057: val_accuracy did not improve from 0.84999
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6565 - accuracy: 0.8513 - val_loss: 0.6970 - val_accuracy: 0.8496
# Epoch 58/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6540 - accuracy: 0.8524
# Epoch 00058: val_accuracy did not improve from 0.84999
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6542 - accuracy: 0.8523 - val_loss: 0.6968 - val_accuracy: 0.8496
# Epoch 59/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6541 - accuracy: 0.8524
# Epoch 00059: val_accuracy improved from 0.84999 to 0.85023, saving model to ./drive/MyDrive/model-gru-59.hdf5
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6544 - accuracy: 0.8522 - val_loss: 0.6961 - val_accuracy: 0.8502
# Epoch 60/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6548 - accuracy: 0.8520
# Epoch 00060: val_accuracy did not improve from 0.85023
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6544 - accuracy: 0.8521 - val_loss: 0.6965 - val_accuracy: 0.8496
# Epoch 61/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6547 - accuracy: 0.8521
# Epoch 00061: val_accuracy did not improve from 0.85023
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6547 - accuracy: 0.8521 - val_loss: 0.6960 - val_accuracy: 0.8497
# Epoch 62/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6538 - accuracy: 0.8520
# Epoch 00062: val_accuracy did not improve from 0.85023
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6535 - accuracy: 0.8520 - val_loss: 0.6964 - val_accuracy: 0.8493
# Epoch 63/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6530 - accuracy: 0.8523
# Epoch 00063: val_accuracy did not improve from 0.85023
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6536 - accuracy: 0.8522 - val_loss: 0.6960 - val_accuracy: 0.8500
# Epoch 64/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6530 - accuracy: 0.8522
# Epoch 00064: val_accuracy did not improve from 0.85023
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6531 - accuracy: 0.8522 - val_loss: 0.6958 - val_accuracy: 0.8499
# Epoch 65/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6522 - accuracy: 0.8522
# Epoch 00065: val_accuracy improved from 0.85023 to 0.85033, saving model to ./drive/MyDrive/model-gru-65.hdf5
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6527 - accuracy: 0.8521 - val_loss: 0.6962 - val_accuracy: 0.8503
# Epoch 66/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6520 - accuracy: 0.8524
# Epoch 00066: val_accuracy did not improve from 0.85033
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6519 - accuracy: 0.8524 - val_loss: 0.6953 - val_accuracy: 0.8499
# Epoch 67/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6512 - accuracy: 0.8529
# Epoch 00067: val_accuracy did not improve from 0.85033
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6513 - accuracy: 0.8528 - val_loss: 0.6959 - val_accuracy: 0.8497
# Epoch 68/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6515 - accuracy: 0.8524
# Epoch 00068: val_accuracy did not improve from 0.85033
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6512 - accuracy: 0.8525 - val_loss: 0.6960 - val_accuracy: 0.8498
# Epoch 69/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6509 - accuracy: 0.8525
# Epoch 00069: val_accuracy did not improve from 0.85033
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6510 - accuracy: 0.8525 - val_loss: 0.6956 - val_accuracy: 0.8502
# Epoch 70/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6513 - accuracy: 0.8524
# Epoch 00070: val_accuracy did not improve from 0.85033
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6512 - accuracy: 0.8523 - val_loss: 0.6956 - val_accuracy: 0.8499
# Epoch 71/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6502 - accuracy: 0.8531
# Epoch 00071: val_accuracy did not improve from 0.85033
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6502 - accuracy: 0.8531 - val_loss: 0.6957 - val_accuracy: 0.8503
# Epoch 72/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6505 - accuracy: 0.8527
# Epoch 00072: val_accuracy did not improve from 0.85033
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6504 - accuracy: 0.8527 - val_loss: 0.6965 - val_accuracy: 0.8499
# Epoch 73/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6503 - accuracy: 0.8526
# Epoch 00073: val_accuracy did not improve from 0.85033
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6502 - accuracy: 0.8526 - val_loss: 0.6966 - val_accuracy: 0.8495
# Epoch 74/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6493 - accuracy: 0.8530
# Epoch 00074: val_accuracy did not improve from 0.85033
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6493 - accuracy: 0.8530 - val_loss: 0.6952 - val_accuracy: 0.8500
# Epoch 75/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6492 - accuracy: 0.8529
# Epoch 00075: val_accuracy did not improve from 0.85033
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6493 - accuracy: 0.8529 - val_loss: 0.6958 - val_accuracy: 0.8500
# Epoch 76/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6492 - accuracy: 0.8528
# Epoch 00076: val_accuracy did not improve from 0.85033
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6493 - accuracy: 0.8527 - val_loss: 0.6953 - val_accuracy: 0.8503
# Epoch 77/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6491 - accuracy: 0.8530
# Epoch 00077: val_accuracy did not improve from 0.85033
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6493 - accuracy: 0.8529 - val_loss: 0.6955 - val_accuracy: 0.8502
# Epoch 78/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6476 - accuracy: 0.8530
# Epoch 00078: val_accuracy improved from 0.85033 to 0.85075, saving model to ./drive/MyDrive/model-gru-78.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6476 - accuracy: 0.8531 - val_loss: 0.6955 - val_accuracy: 0.8507
# Epoch 79/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6489 - accuracy: 0.8527
# Epoch 00079: val_accuracy did not improve from 0.85075
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6488 - accuracy: 0.8528 - val_loss: 0.6948 - val_accuracy: 0.8503
# Epoch 80/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6465 - accuracy: 0.8533
# Epoch 00080: val_accuracy did not improve from 0.85075
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6465 - accuracy: 0.8533 - val_loss: 0.6952 - val_accuracy: 0.8501
# Epoch 81/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6478 - accuracy: 0.8530
# Epoch 00081: val_accuracy did not improve from 0.85075
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6476 - accuracy: 0.8530 - val_loss: 0.6947 - val_accuracy: 0.8499
# Epoch 82/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6470 - accuracy: 0.8535
# Epoch 00082: val_accuracy did not improve from 0.85075
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6473 - accuracy: 0.8535 - val_loss: 0.6960 - val_accuracy: 0.8500
# Epoch 83/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6469 - accuracy: 0.8531
# Epoch 00083: val_accuracy did not improve from 0.85075
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6469 - accuracy: 0.8531 - val_loss: 0.6954 - val_accuracy: 0.8501
# Epoch 84/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6475 - accuracy: 0.8530
# Epoch 00084: val_accuracy did not improve from 0.85075
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6474 - accuracy: 0.8530 - val_loss: 0.6943 - val_accuracy: 0.8505
# Epoch 85/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6462 - accuracy: 0.8536
# Epoch 00085: val_accuracy improved from 0.85075 to 0.85077, saving model to ./drive/MyDrive/model-gru-85.hdf5
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6464 - accuracy: 0.8535 - val_loss: 0.6939 - val_accuracy: 0.8508
# Epoch 86/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6457 - accuracy: 0.8535
# Epoch 00086: val_accuracy did not improve from 0.85077
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6459 - accuracy: 0.8534 - val_loss: 0.6947 - val_accuracy: 0.8503
# Epoch 87/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6461 - accuracy: 0.8537
# Epoch 00087: val_accuracy did not improve from 0.85077
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6461 - accuracy: 0.8536 - val_loss: 0.6944 - val_accuracy: 0.8506
# Epoch 88/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6460 - accuracy: 0.8534
# Epoch 00088: val_accuracy did not improve from 0.85077
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6462 - accuracy: 0.8534 - val_loss: 0.6946 - val_accuracy: 0.8507
# Epoch 89/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6452 - accuracy: 0.8536
# Epoch 00089: val_accuracy did not improve from 0.85077
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6453 - accuracy: 0.8536 - val_loss: 0.6954 - val_accuracy: 0.8503
# Epoch 90/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6449 - accuracy: 0.8534
# Epoch 00090: val_accuracy did not improve from 0.85077
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6451 - accuracy: 0.8534 - val_loss: 0.6949 - val_accuracy: 0.8500
# Epoch 91/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6442 - accuracy: 0.8537
# Epoch 00091: val_accuracy did not improve from 0.85077
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6446 - accuracy: 0.8536 - val_loss: 0.6950 - val_accuracy: 0.8500
# Epoch 92/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6453 - accuracy: 0.8537
# Epoch 00092: val_accuracy improved from 0.85077 to 0.85100, saving model to ./drive/MyDrive/model-gru-92.hdf5
# 282/282 [==============================] - 3s 12ms/step - loss: 0.6454 - accuracy: 0.8536 - val_loss: 0.6943 - val_accuracy: 0.8510
# Epoch 93/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6444 - accuracy: 0.8539
# Epoch 00093: val_accuracy did not improve from 0.85100
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6450 - accuracy: 0.8538 - val_loss: 0.6944 - val_accuracy: 0.8506
# Epoch 94/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6444 - accuracy: 0.8536
# Epoch 00094: val_accuracy did not improve from 0.85100
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6443 - accuracy: 0.8536 - val_loss: 0.6944 - val_accuracy: 0.8505
# Epoch 95/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6427 - accuracy: 0.8538
# Epoch 00095: val_accuracy did not improve from 0.85100
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6429 - accuracy: 0.8538 - val_loss: 0.6949 - val_accuracy: 0.8501
# Epoch 96/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6434 - accuracy: 0.8536
# Epoch 00096: val_accuracy did not improve from 0.85100
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6430 - accuracy: 0.8537 - val_loss: 0.6949 - val_accuracy: 0.8503
# Epoch 97/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6434 - accuracy: 0.8541
# Epoch 00097: val_accuracy did not improve from 0.85100
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6434 - accuracy: 0.8541 - val_loss: 0.6945 - val_accuracy: 0.8508
# Epoch 98/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6428 - accuracy: 0.8542
# Epoch 00098: val_accuracy did not improve from 0.85100
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6428 - accuracy: 0.8542 - val_loss: 0.6947 - val_accuracy: 0.8505
# Epoch 99/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6430 - accuracy: 0.8537
# Epoch 00099: val_accuracy did not improve from 0.85100
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6430 - accuracy: 0.8537 - val_loss: 0.6945 - val_accuracy: 0.8506
# Epoch 100/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6426 - accuracy: 0.8542
# Epoch 00100: val_accuracy did not improve from 0.85100
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6426 - accuracy: 0.8542 - val_loss: 0.6944 - val_accuracy: 0.8506
# Epoch 101/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6389 - accuracy: 0.8547
# Epoch 00101: val_accuracy improved from 0.85100 to 0.85103, saving model to ./drive/MyDrive/model-gru-101.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6388 - accuracy: 0.8548 - val_loss: 0.6930 - val_accuracy: 0.8510
# Epoch 102/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6383 - accuracy: 0.8548
# Epoch 00102: val_accuracy improved from 0.85103 to 0.85118, saving model to ./drive/MyDrive/model-gru-102.hdf5
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6387 - accuracy: 0.8548 - val_loss: 0.6929 - val_accuracy: 0.8512
# Epoch 103/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6380 - accuracy: 0.8554
# Epoch 00103: val_accuracy did not improve from 0.85118
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6378 - accuracy: 0.8555 - val_loss: 0.6923 - val_accuracy: 0.8510
# Epoch 104/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6375 - accuracy: 0.8550
# Epoch 00104: val_accuracy improved from 0.85118 to 0.85126, saving model to ./drive/MyDrive/model-gru-104.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6378 - accuracy: 0.8549 - val_loss: 0.6922 - val_accuracy: 0.8513
# Epoch 105/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6371 - accuracy: 0.8550
# Epoch 00105: val_accuracy did not improve from 0.85126
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6371 - accuracy: 0.8550 - val_loss: 0.6925 - val_accuracy: 0.8508
# Epoch 106/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6378 - accuracy: 0.8550
# Epoch 00106: val_accuracy improved from 0.85126 to 0.85137, saving model to ./drive/MyDrive/model-gru-106.hdf5
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6376 - accuracy: 0.8550 - val_loss: 0.6918 - val_accuracy: 0.8514
# Epoch 107/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6369 - accuracy: 0.8549
# Epoch 00107: val_accuracy did not improve from 0.85137
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6366 - accuracy: 0.8550 - val_loss: 0.6923 - val_accuracy: 0.8510
# Epoch 108/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6374 - accuracy: 0.8552
# Epoch 00108: val_accuracy did not improve from 0.85137
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6371 - accuracy: 0.8553 - val_loss: 0.6923 - val_accuracy: 0.8510
# Epoch 109/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6370 - accuracy: 0.8553
# Epoch 00109: val_accuracy did not improve from 0.85137
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6371 - accuracy: 0.8553 - val_loss: 0.6922 - val_accuracy: 0.8511
# Epoch 110/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6374 - accuracy: 0.8552
# Epoch 00110: val_accuracy did not improve from 0.85137
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6374 - accuracy: 0.8552 - val_loss: 0.6926 - val_accuracy: 0.8512
# Epoch 111/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6370 - accuracy: 0.8554
# Epoch 00111: val_accuracy did not improve from 0.85137
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6371 - accuracy: 0.8554 - val_loss: 0.6921 - val_accuracy: 0.8512
# Epoch 112/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6360 - accuracy: 0.8555
# Epoch 00112: val_accuracy did not improve from 0.85137
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6361 - accuracy: 0.8555 - val_loss: 0.6923 - val_accuracy: 0.8512
# Epoch 113/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6372 - accuracy: 0.8550
# Epoch 00113: val_accuracy improved from 0.85137 to 0.85146, saving model to ./drive/MyDrive/model-gru-113.hdf5
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6370 - accuracy: 0.8551 - val_loss: 0.6919 - val_accuracy: 0.8515
# Epoch 114/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6369 - accuracy: 0.8554
# Epoch 00114: val_accuracy did not improve from 0.85146
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6369 - accuracy: 0.8554 - val_loss: 0.6927 - val_accuracy: 0.8511
# Epoch 115/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6367 - accuracy: 0.8551
# Epoch 00115: val_accuracy improved from 0.85146 to 0.85157, saving model to ./drive/MyDrive/model-gru-115.hdf5
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6366 - accuracy: 0.8551 - val_loss: 0.6925 - val_accuracy: 0.8516
# Epoch 116/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6359 - accuracy: 0.8553
# Epoch 00116: val_accuracy did not improve from 0.85157
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6361 - accuracy: 0.8553 - val_loss: 0.6923 - val_accuracy: 0.8511
# Epoch 117/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6358 - accuracy: 0.8553
# Epoch 00117: val_accuracy did not improve from 0.85157
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6356 - accuracy: 0.8553 - val_loss: 0.6919 - val_accuracy: 0.8512
# Epoch 118/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6370 - accuracy: 0.8551
# Epoch 00118: val_accuracy did not improve from 0.85157
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6364 - accuracy: 0.8552 - val_loss: 0.6925 - val_accuracy: 0.8511
# Epoch 119/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6362 - accuracy: 0.8553
# Epoch 00119: val_accuracy did not improve from 0.85157
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6362 - accuracy: 0.8553 - val_loss: 0.6920 - val_accuracy: 0.8509
# Epoch 120/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6364 - accuracy: 0.8552
# Epoch 00120: val_accuracy did not improve from 0.85157
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6363 - accuracy: 0.8552 - val_loss: 0.6921 - val_accuracy: 0.8513
# Epoch 121/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6357 - accuracy: 0.8554
# Epoch 00121: val_accuracy did not improve from 0.85157
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6360 - accuracy: 0.8554 - val_loss: 0.6915 - val_accuracy: 0.8514
# Epoch 122/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6364 - accuracy: 0.8550
# Epoch 00122: val_accuracy did not improve from 0.85157
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6361 - accuracy: 0.8551 - val_loss: 0.6920 - val_accuracy: 0.8510
# Epoch 123/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6357 - accuracy: 0.8556
# Epoch 00123: val_accuracy did not improve from 0.85157
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6356 - accuracy: 0.8556 - val_loss: 0.6921 - val_accuracy: 0.8516
# Epoch 124/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6354 - accuracy: 0.8553
# Epoch 00124: val_accuracy did not improve from 0.85157
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6357 - accuracy: 0.8553 - val_loss: 0.6920 - val_accuracy: 0.8514
# Epoch 125/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6352 - accuracy: 0.8553
# Epoch 00125: val_accuracy did not improve from 0.85157
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6353 - accuracy: 0.8552 - val_loss: 0.6919 - val_accuracy: 0.8514
# Epoch 126/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6353 - accuracy: 0.8553
# Epoch 00126: val_accuracy did not improve from 0.85157
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6353 - accuracy: 0.8553 - val_loss: 0.6921 - val_accuracy: 0.8513
# Epoch 127/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6354 - accuracy: 0.8554
# Epoch 00127: val_accuracy did not improve from 0.85157
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6352 - accuracy: 0.8554 - val_loss: 0.6917 - val_accuracy: 0.8515
# Epoch 128/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6357 - accuracy: 0.8554
# Epoch 00128: val_accuracy improved from 0.85157 to 0.85162, saving model to ./drive/MyDrive/model-gru-128.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6356 - accuracy: 0.8554 - val_loss: 0.6925 - val_accuracy: 0.8516
# Epoch 129/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6344 - accuracy: 0.8558
# Epoch 00129: val_accuracy did not improve from 0.85162
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6344 - accuracy: 0.8558 - val_loss: 0.6919 - val_accuracy: 0.8516
# Epoch 130/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6341 - accuracy: 0.8557
# Epoch 00130: val_accuracy did not improve from 0.85162
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6341 - accuracy: 0.8557 - val_loss: 0.6920 - val_accuracy: 0.8516
# Epoch 131/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6354 - accuracy: 0.8553
# Epoch 00131: val_accuracy did not improve from 0.85162
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6351 - accuracy: 0.8553 - val_loss: 0.6918 - val_accuracy: 0.8509
# Epoch 132/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6349 - accuracy: 0.8556
# Epoch 00132: val_accuracy did not improve from 0.85162
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6345 - accuracy: 0.8558 - val_loss: 0.6920 - val_accuracy: 0.8510
# Epoch 133/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6343 - accuracy: 0.8558
# Epoch 00133: val_accuracy did not improve from 0.85162
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6344 - accuracy: 0.8558 - val_loss: 0.6923 - val_accuracy: 0.8515
# Epoch 134/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6342 - accuracy: 0.8554
# Epoch 00134: val_accuracy did not improve from 0.85162
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6340 - accuracy: 0.8554 - val_loss: 0.6922 - val_accuracy: 0.8516
# Epoch 135/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6345 - accuracy: 0.8557
# Epoch 00135: val_accuracy did not improve from 0.85162
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6343 - accuracy: 0.8557 - val_loss: 0.6917 - val_accuracy: 0.8514
# Epoch 136/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6334 - accuracy: 0.8560
# Epoch 00136: val_accuracy improved from 0.85162 to 0.85168, saving model to ./drive/MyDrive/model-gru-136.hdf5
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6333 - accuracy: 0.8560 - val_loss: 0.6918 - val_accuracy: 0.8517
# Epoch 137/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6335 - accuracy: 0.8560
# Epoch 00137: val_accuracy did not improve from 0.85168
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6336 - accuracy: 0.8560 - val_loss: 0.6921 - val_accuracy: 0.8516
# Epoch 138/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6345 - accuracy: 0.8553
# Epoch 00138: val_accuracy did not improve from 0.85168
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6342 - accuracy: 0.8553 - val_loss: 0.6920 - val_accuracy: 0.8514
# Epoch 139/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6340 - accuracy: 0.8556
# Epoch 00139: val_accuracy did not improve from 0.85168
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6341 - accuracy: 0.8556 - val_loss: 0.6918 - val_accuracy: 0.8516
# Epoch 140/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6332 - accuracy: 0.8557
# Epoch 00140: val_accuracy did not improve from 0.85168
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6332 - accuracy: 0.8557 - val_loss: 0.6924 - val_accuracy: 0.8516
# Epoch 141/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6333 - accuracy: 0.8559
# Epoch 00141: val_accuracy improved from 0.85168 to 0.85178, saving model to ./drive/MyDrive/model-gru-141.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6329 - accuracy: 0.8559 - val_loss: 0.6922 - val_accuracy: 0.8518
# Epoch 142/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6334 - accuracy: 0.8558
# Epoch 00142: val_accuracy did not improve from 0.85178
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6336 - accuracy: 0.8557 - val_loss: 0.6925 - val_accuracy: 0.8513
# Epoch 143/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6338 - accuracy: 0.8555
# Epoch 00143: val_accuracy did not improve from 0.85178
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6338 - accuracy: 0.8555 - val_loss: 0.6920 - val_accuracy: 0.8513
# Epoch 144/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6329 - accuracy: 0.8563
# Epoch 00144: val_accuracy did not improve from 0.85178
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6331 - accuracy: 0.8563 - val_loss: 0.6920 - val_accuracy: 0.8510
# Epoch 145/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6334 - accuracy: 0.8559
# Epoch 00145: val_accuracy did not improve from 0.85178
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6333 - accuracy: 0.8559 - val_loss: 0.6917 - val_accuracy: 0.8517
# Epoch 146/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6328 - accuracy: 0.8560
# Epoch 00146: val_accuracy did not improve from 0.85178
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6329 - accuracy: 0.8560 - val_loss: 0.6920 - val_accuracy: 0.8516
# Epoch 147/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6330 - accuracy: 0.8557
# Epoch 00147: val_accuracy did not improve from 0.85178
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6330 - accuracy: 0.8557 - val_loss: 0.6919 - val_accuracy: 0.8513
# Epoch 148/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6325 - accuracy: 0.8558
# Epoch 00148: val_accuracy did not improve from 0.85178
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6325 - accuracy: 0.8558 - val_loss: 0.6919 - val_accuracy: 0.8510
# Epoch 149/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6323 - accuracy: 0.8559
# Epoch 00149: val_accuracy did not improve from 0.85178
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6324 - accuracy: 0.8558 - val_loss: 0.6918 - val_accuracy: 0.8516
# Epoch 150/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6327 - accuracy: 0.8558
# Epoch 00150: val_accuracy did not improve from 0.85178
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6327 - accuracy: 0.8558 - val_loss: 0.6923 - val_accuracy: 0.8514
# Epoch 151/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6296 - accuracy: 0.8569
# Epoch 00151: val_accuracy improved from 0.85178 to 0.85194, saving model to ./drive/MyDrive/model-gru-151.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6300 - accuracy: 0.8569 - val_loss: 0.6913 - val_accuracy: 0.8519
# Epoch 152/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6309 - accuracy: 0.8564
# Epoch 00152: val_accuracy did not improve from 0.85194
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6309 - accuracy: 0.8564 - val_loss: 0.6913 - val_accuracy: 0.8519
# Epoch 153/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6308 - accuracy: 0.8561
# Epoch 00153: val_accuracy did not improve from 0.85194
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6306 - accuracy: 0.8562 - val_loss: 0.6911 - val_accuracy: 0.8517
# Epoch 154/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6306 - accuracy: 0.8565
# Epoch 00154: val_accuracy did not improve from 0.85194
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6307 - accuracy: 0.8565 - val_loss: 0.6908 - val_accuracy: 0.8517
# Epoch 155/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6310 - accuracy: 0.8562
# Epoch 00155: val_accuracy did not improve from 0.85194
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6307 - accuracy: 0.8562 - val_loss: 0.6911 - val_accuracy: 0.8517
# Epoch 156/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6299 - accuracy: 0.8567
# Epoch 00156: val_accuracy did not improve from 0.85194
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6299 - accuracy: 0.8567 - val_loss: 0.6912 - val_accuracy: 0.8517
# Epoch 157/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6312 - accuracy: 0.8560
# Epoch 00157: val_accuracy did not improve from 0.85194
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6312 - accuracy: 0.8560 - val_loss: 0.6910 - val_accuracy: 0.8517
# Epoch 158/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6307 - accuracy: 0.8559
# Epoch 00158: val_accuracy did not improve from 0.85194
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6307 - accuracy: 0.8560 - val_loss: 0.6912 - val_accuracy: 0.8513
# Epoch 159/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6300 - accuracy: 0.8565
# Epoch 00159: val_accuracy did not improve from 0.85194
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6303 - accuracy: 0.8563 - val_loss: 0.6911 - val_accuracy: 0.8519
# Epoch 160/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6306 - accuracy: 0.8561
# Epoch 00160: val_accuracy improved from 0.85194 to 0.85204, saving model to ./drive/MyDrive/model-gru-160.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6307 - accuracy: 0.8561 - val_loss: 0.6910 - val_accuracy: 0.8520
# Epoch 161/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6305 - accuracy: 0.8565
# Epoch 00161: val_accuracy did not improve from 0.85204
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6302 - accuracy: 0.8566 - val_loss: 0.6912 - val_accuracy: 0.8516
# Epoch 162/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6300 - accuracy: 0.8561
# Epoch 00162: val_accuracy improved from 0.85204 to 0.85222, saving model to ./drive/MyDrive/model-gru-162.hdf5
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6300 - accuracy: 0.8561 - val_loss: 0.6910 - val_accuracy: 0.8522
# Epoch 163/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6304 - accuracy: 0.8562
# Epoch 00163: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6300 - accuracy: 0.8562 - val_loss: 0.6908 - val_accuracy: 0.8517
# Epoch 164/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6295 - accuracy: 0.8567
# Epoch 00164: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6296 - accuracy: 0.8567 - val_loss: 0.6909 - val_accuracy: 0.8519
# Epoch 165/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6295 - accuracy: 0.8568
# Epoch 00165: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6295 - accuracy: 0.8568 - val_loss: 0.6906 - val_accuracy: 0.8519
# Epoch 166/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6299 - accuracy: 0.8565
# Epoch 00166: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6299 - accuracy: 0.8565 - val_loss: 0.6908 - val_accuracy: 0.8519
# Epoch 167/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6303 - accuracy: 0.8565
# Epoch 00167: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6303 - accuracy: 0.8565 - val_loss: 0.6907 - val_accuracy: 0.8520
# Epoch 168/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6293 - accuracy: 0.8565
# Epoch 00168: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6289 - accuracy: 0.8566 - val_loss: 0.6909 - val_accuracy: 0.8520
# Epoch 169/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6303 - accuracy: 0.8564
# Epoch 00169: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6304 - accuracy: 0.8564 - val_loss: 0.6909 - val_accuracy: 0.8516
# Epoch 170/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6302 - accuracy: 0.8564
# Epoch 00170: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6305 - accuracy: 0.8563 - val_loss: 0.6907 - val_accuracy: 0.8518
# Epoch 171/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6295 - accuracy: 0.8565
# Epoch 00171: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6296 - accuracy: 0.8565 - val_loss: 0.6909 - val_accuracy: 0.8519
# Epoch 172/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6294 - accuracy: 0.8564
# Epoch 00172: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6293 - accuracy: 0.8564 - val_loss: 0.6907 - val_accuracy: 0.8519
# Epoch 173/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6293 - accuracy: 0.8563
# Epoch 00173: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6291 - accuracy: 0.8564 - val_loss: 0.6909 - val_accuracy: 0.8519
# Epoch 174/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6298 - accuracy: 0.8561
# Epoch 00174: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6297 - accuracy: 0.8561 - val_loss: 0.6909 - val_accuracy: 0.8519
# Epoch 175/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6302 - accuracy: 0.8563
# Epoch 00175: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6301 - accuracy: 0.8563 - val_loss: 0.6910 - val_accuracy: 0.8517
# Epoch 176/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6296 - accuracy: 0.8563
# Epoch 00176: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6295 - accuracy: 0.8563 - val_loss: 0.6908 - val_accuracy: 0.8516
# Epoch 177/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6289 - accuracy: 0.8569
# Epoch 00177: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6290 - accuracy: 0.8569 - val_loss: 0.6911 - val_accuracy: 0.8520
# Epoch 178/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6292 - accuracy: 0.8563
# Epoch 00178: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6291 - accuracy: 0.8564 - val_loss: 0.6910 - val_accuracy: 0.8516
# Epoch 179/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6291 - accuracy: 0.8565
# Epoch 00179: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6291 - accuracy: 0.8565 - val_loss: 0.6908 - val_accuracy: 0.8518
# Epoch 180/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6291 - accuracy: 0.8564
# Epoch 00180: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6291 - accuracy: 0.8564 - val_loss: 0.6907 - val_accuracy: 0.8520
# Epoch 181/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6284 - accuracy: 0.8565
# Epoch 00181: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6290 - accuracy: 0.8564 - val_loss: 0.6909 - val_accuracy: 0.8518
# Epoch 182/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6291 - accuracy: 0.8570
# Epoch 00182: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6290 - accuracy: 0.8570 - val_loss: 0.6909 - val_accuracy: 0.8519
# Epoch 183/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6290 - accuracy: 0.8567
# Epoch 00183: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6291 - accuracy: 0.8567 - val_loss: 0.6909 - val_accuracy: 0.8520
# Epoch 184/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6287 - accuracy: 0.8565
# Epoch 00184: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6291 - accuracy: 0.8564 - val_loss: 0.6908 - val_accuracy: 0.8521
# Epoch 185/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6285 - accuracy: 0.8567
# Epoch 00185: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6283 - accuracy: 0.8568 - val_loss: 0.6909 - val_accuracy: 0.8518
# Epoch 186/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6286 - accuracy: 0.8566
# Epoch 00186: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6283 - accuracy: 0.8567 - val_loss: 0.6908 - val_accuracy: 0.8521
# Epoch 187/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6283 - accuracy: 0.8568
# Epoch 00187: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6281 - accuracy: 0.8568 - val_loss: 0.6907 - val_accuracy: 0.8517
# Epoch 188/200
# 281/282 [============================>.] - ETA: 0s - loss: 0.6281 - accuracy: 0.8563
# Epoch 00188: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6281 - accuracy: 0.8563 - val_loss: 0.6910 - val_accuracy: 0.8516
# Epoch 189/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6278 - accuracy: 0.8563
# Epoch 00189: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6279 - accuracy: 0.8563 - val_loss: 0.6910 - val_accuracy: 0.8519
# Epoch 190/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6283 - accuracy: 0.8568
# Epoch 00190: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6286 - accuracy: 0.8567 - val_loss: 0.6911 - val_accuracy: 0.8517
# Epoch 191/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6289 - accuracy: 0.8565
# Epoch 00191: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6290 - accuracy: 0.8564 - val_loss: 0.6911 - val_accuracy: 0.8519
# Epoch 192/200
# 282/282 [==============================] - ETA: 0s - loss: 0.6280 - accuracy: 0.8568
# Epoch 00192: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6280 - accuracy: 0.8568 - val_loss: 0.6908 - val_accuracy: 0.8516
# Epoch 193/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6281 - accuracy: 0.8569
# Epoch 00193: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6284 - accuracy: 0.8568 - val_loss: 0.6910 - val_accuracy: 0.8521
# Epoch 194/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6277 - accuracy: 0.8570
# Epoch 00194: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6281 - accuracy: 0.8569 - val_loss: 0.6911 - val_accuracy: 0.8515
# Epoch 195/200
# 276/282 [============================>.] - ETA: 0s - loss: 0.6297 - accuracy: 0.8565
# Epoch 00195: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6297 - accuracy: 0.8566 - val_loss: 0.6909 - val_accuracy: 0.8518
# Epoch 196/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6287 - accuracy: 0.8563
# Epoch 00196: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6287 - accuracy: 0.8563 - val_loss: 0.6910 - val_accuracy: 0.8519
# Epoch 197/200
# 277/282 [============================>.] - ETA: 0s - loss: 0.6288 - accuracy: 0.8564
# Epoch 00197: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6286 - accuracy: 0.8564 - val_loss: 0.6908 - val_accuracy: 0.8516
# Epoch 198/200
# 278/282 [============================>.] - ETA: 0s - loss: 0.6279 - accuracy: 0.8565
# Epoch 00198: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6283 - accuracy: 0.8564 - val_loss: 0.6910 - val_accuracy: 0.8516
# Epoch 199/200
# 280/282 [============================>.] - ETA: 0s - loss: 0.6269 - accuracy: 0.8570
# Epoch 00199: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 11ms/step - loss: 0.6270 - accuracy: 0.8569 - val_loss: 0.6911 - val_accuracy: 0.8520
# Epoch 200/200
# 279/282 [============================>.] - ETA: 0s - loss: 0.6280 - accuracy: 0.8571
# Epoch 00200: val_accuracy did not improve from 0.85222
# 282/282 [==============================] - 3s 10ms/step - loss: 0.6281 - accuracy: 0.8570 - val_loss: 0.6909 - val_accuracy: 0.8516
